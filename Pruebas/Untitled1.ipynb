# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
red=cv2.imread("Ej/ex.jpg",1)
red[:,:,0]=0
red[:,:,1]=0
blue=cv2.imread("Ej/ex.jpg",1)
blue[:,:,1]=0
blue[:,:,2]=0
green=cv2.imread("Ej/ex.jpg",1)
green[:,:,0]=0
green[:,:,2]=0
img=cv2.imread("Ej/ex.jpg",1)
N,M = img.shape[:2]
#cv2.imshow('red',red[:,:,2])
##cv2.imshow('blue',blue[:,:,0])
#cv2.imshow('green',green[:,:,1])
#cv2.waitKey(0)
#cv2.destroyAllWindows()
plt.imshow(img[(N*3/4 -30)-10:(N*3/4-30)+10, (M/4 +20)-10:(M/4+20)+10], cmap=plt.cm.gray, interpolation='bicubic')
plt.title('Pixeles')

# Adjust the subplot layout, because the logit one may take more space
# than usual, due to labels 
plt.subplots_adjust(top=0.95, bottom=0.05, left=0.10, right=0.95, hspace=0.25, wspace=0.35)

plt.show()
